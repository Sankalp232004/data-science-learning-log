# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('owid-covid-data.csv')

# Display the first few rows to confirm it loaded correctly
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
# Get a summary of the DataFrame, including data types and non-null counts
df.info()

# Get descriptive statistics for numerical columns
df.describe()

# Check for the total number of missing values in each column
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350085 entries, 0 to 350084
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    350085 non-null  object
#  1   continent                                   333420 non-null  object
#  2   location                                    350085 non-null  object
#  3   date                                        350085 non-null  object
#  4   total_cases                                 312088 non-null  float64
#  5   new_cases                                   340457 non-null  float64
#  6   new_cases_smoothed                          339198 non-null  float64
#  7   total_deaths                                290501 non-null  float64
#  8   new_deaths                                  340511 non-null  float64
# ...

# %%
# Fill missing values in 'total_cases' with 0
df['total_cases'] = df['total_cases'].fillna(0)

# Check the number of missing values again to verify the cleaning
print("Missing values in 'total_cases' after cleaning:")
print(df['total_cases'].isnull().sum())
# Out:
# Missing values in 'total_cases' after cleaning:
# 0

# %%
import matplotlib.pyplot as plt

# Filter data for a specific country (e.g., 'India')
india_df = df[df['location'] == 'India']

# Convert the 'date' column to datetime objects for proper plotting
india_df['date'] = pd.to_datetime(india_df['date'])

# Create a line chart of total cases over time
plt.figure(figsize=(12, 7))
plt.plot(india_df['date'], india_df['total_cases'], label='Total Cases')
plt.title('Total COVID-19 Cases in India Over Time')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# /var/folders/tc/r_9v6dkj5pj7c0ymq4f7hsyr0000gn/T/ipykernel_47712/2254147226.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_df['date'] = pd.to_datetime(india_df['date'])
