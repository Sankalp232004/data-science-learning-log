# %%
import os
import pandas as pd

# This path should be the exact path to your folder where the CSV files are located.
# The `ls` command in the terminal (or Finder on Mac) will show you the exact folder name.
folder_path = '/Users/sankalpmishra/Desktop/Projects/IPL Data/IPL_2008_to_2022_All_Match_Dataset'

# Use os.path.join to create the correct file paths
ball_by_ball_path = os.path.join(folder_path, 'IPL_Ball_by_Ball_2008_2022.csv')
matches_path = os.path.join(folder_path, 'IPL_Matches_2008_2022.csv')

# Load the data into DataFrames
ball_by_ball_df = pd.read_csv(ball_by_ball_path)
matches_df = pd.read_csv(matches_path)

# %%
# Display the first 5 rows of the ball_by_ball data
print("Ball-by-Ball Data:")
display(ball_by_ball_df.head())

# Get a summary of the matches data
print("\nMatches Data Info:")
matches_df.info()

# Get descriptive statistics for numerical columns in the matches data
print("\nMatches Data Description:")
display(matches_df.describe())
# Out:
# Ball-by-Ball Data:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...
